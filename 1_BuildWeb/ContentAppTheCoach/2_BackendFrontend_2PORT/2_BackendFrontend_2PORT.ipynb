# %% [markdown]
# # 1. Refactor the code 0_baseJS_HTML

# %% [markdown]
# **Lưu ý quan trọng:**
# 1. Luôn thêm `.env` vào file `.gitignore` để tránh đẩy API key lên GitHub
# 2. Không bao giờ để lộ API key trong code frontend vì người dùng có thể nhìn thấy
# 3. Cách tốt nhất là xử lý API key ở phía backend và tạo một API endpoint riêng để frontend gọi đến
#
# Nếu bạn đang làm dự án production, nên tạo một backend server để xử lý các cuộc gọi API và bảo vệ API key của bạn.

# %% [markdown]
# I'll help you refactor the baseJS_HTML code to make it more organized and maintainable. Here's the refactored version:
#
# 1. First, let's restructure the project to follow a better organization:
#
# ```
# baseJS_HTML/
# ├── src/
# │   ├── js/
# │   │   ├── api.js
# │   │   ├── ui.js
# │   │   └── main.js
# │   ├── css/
# │   │   └── style.css
# │   └── index.html
# ├── .env
# └── server.js
# ```
#
#
# 1. Create a `.env` file in the root directory with your OpenAI API key:
# ```
# OPENAI_API_KEY=your_api_key_here
# ```
#
# 2. Install dependencies:
# ```bash
# npm install express cors dotenv axios
# ```
#
# 3. Run the server:
# ```bash
# node server.js
# ```
#
# This refactored version provides better maintainability, error handling, and user experience while keeping the core functionality intact.

# %% [markdown]
# # 2. Chia ra thành Backend và Frontend

# %% [markdown]
# I'll help you split this into a proper backend and frontend structure. Here's the recommended organization:
#
# ```
# project/
# ├── backend/                  # Thư mục chứa toàn bộ mã nguồn và cấu hình của Backend
# │   ├── src/                  # Thư mục chính chứa mã nguồn của backend
# │   │   ├── controllers/      # Thư mục chứa các controller - nơi xử lý logic của từng endpoint
# │   │   ├── routes/           # Thư mục chứa các file định tuyến, định nghĩa các endpoint và gắn với controller tương ứng
# │   │   ├── config/           # Thư mục chứa các file cấu hình (như cấu hình cơ sở dữ liệu, API key, ... nếu cần)
# │   │   └── server.js         # File chính để khởi động server và kết nối các thành phần của backend
# │   ├── .env                  # File chứa các biến môi trường, lưu trữ thông tin nhạy cảm như API key, database URL, ...
# │   └── package.json          # File quản lý các gói phụ thuộc và thông tin về dự án backend (scripts, dependencies)
# └── frontend/                 # Thư mục chứa toàn bộ mã nguồn và cấu hình của Frontend
#     ├── src/                  # Thư mục chính chứa mã nguồn của frontend
#     │   ├── js/               # Thư mục chứa các file JavaScript phục vụ cho frontend (logic giao diện người dùng)
#     │   ├── css/              # Thư mục chứa các file CSS dùng để định dạng giao diện
#     │   └── index.html        # File HTML chính, đóng vai trò là giao diện người dùng
#     └── package.json          # File quản lý các gói phụ thuộc và thông tin về dự án frontend (scripts, dependencies)
#
# ```
#
# Here's the implementation:
#
# ### Backend
#
# ```javascript:backend/src/controllers/questionController.js
# const axios = require('axios');
#
# class QuestionController {
#     async generateQuestions(req, res) {
#         try {
#             const { topic, level } = req.body;
#
#             if (!topic || !level) {
#                 return res.status(400).json({
#                     error: 'Topic and level are required'
#                 });
#             }
#
#             const prompt = `Generate ${level} level questions on the topic of ${topic}.`;
#
#             const response = await axios.post(
#                 'https://api.openai.com/v1/chat/completions',
#                 {
#                     model: 'gpt-4',
#                     messages: [{ role: 'user', content: prompt }]
#                 },
#                 {
#                     headers: {
#                         'Authorization': `Bearer ${process.env.OPENAI_API_KEY}`,
#                         'Content-Type': 'application/json'
#                     }
#                 }
#             );
#
#             res.json({
#                 questions: response.data.choices[0].message.content
#             });
#         } catch (error) {
#             console.error('API Error:', error);
#             res.status(500).json({
#                 error: 'Failed to generate questions'
#             });
#         }
#     }
# }
#
# module.exports = new QuestionController();
# ```
#
# ```javascript:backend/src/routes/questionRoutes.js
# const express = require('express');
# const questionController = require('../controllers/questionController');
#
# const router = express.Router();
#
# router.post('/generate', questionController.generateQuestions);
#
# module.exports = router;
# ```
#
# ```javascript:backend/src/server.js
# const express = require('express');
# const cors = require('cors');
# const dotenv = require('dotenv');
# const questionRoutes = require('./routes/questionRoutes');
#
# dotenv.config();
#
# const app = express();
# const PORT = process.env.PORT || 3000;
#
# app.use(cors());
# app.use(express.json());
#
# app.use('/api/questions', questionRoutes);
#
# app.listen(PORT, () => {
#     console.log(`Server running on port ${PORT}`);
# });
# ```
#
# ### Frontend
#
# ```javascript:frontend/src/js/api.js
# const API_URL = 'http://localhost:3000/api/questions';
#
# export async function generateQuestions(topic, level) {
#     try {
#         const response = await fetch(`${API_URL}/generate`, {
#             method: 'POST',
#             headers: {
#                 'Content-Type': 'application/json'
#             },
#             body: JSON.stringify({ topic, level })
#         });
#
#         if (!response.ok) {
#             throw new Error('Failed to generate questions');
#         }
#
#         const data = await response.json();
#         return data.questions;
#     } catch (error) {
#         throw new Error(`Error: ${error.message}`);
#     }
# }
# ```
#
# ```javascript:frontend/src/js/ui.js
# export class UI {
#     constructor() {
#         this.topicInput = document.getElementById('topic');
#         this.levelSelect = document.getElementById('level');
#         this.generateBtn = document.getElementById('generate-btn');
#         this.questionContainer = document.getElementById('question-container');
#         this.loadingDialog = document.getElementById('loading-dialog');
#     }
#
#     showLoading() {
#         this.loadingDialog.style.display = 'flex';
#     }
#
#     hideLoading() {
#         this.loadingDialog.style.display = 'none';
#     }
#
#     displayQuestions(questions) {
#         this.questionContainer.innerHTML = `<p>${questions}</p>`;
#     }
#
#     displayError(message) {
#         this.questionContainer.innerHTML = `
#             <div class="error">
#                 ${message}
#             </div>
#         `;
#     }
#
#     getInputValues() {
#         return {
#             topic: this.topicInput.value,
#             level: this.levelSelect.value
#         };
#     }
# }
# ```
#
# ```javascript:frontend/src/js/main.js
# import { UI } from './ui.js';
# import { generateQuestions } from './api.js';
#
# class App {
#     constructor() {
#         this.ui = new UI();
#         this.initialize();
#     }
#
#     initialize() {
#         this.ui.generateBtn.addEventListener('click', this.handleGenerate.bind(this));
#     }
#
#     async handleGenerate() {
#         const { topic, level } = this.ui.getInputValues();
#
#         if (!topic) {
#             this.ui.displayError('Please enter a topic');
#             return;
#         }
#
#         try {
#             this.ui.showLoading();
#             const questions = await generateQuestions(topic, level);
#             this.ui.displayQuestions(questions);
#         } catch (error) {
#             this.ui.displayError(error.message);
#         } finally {
#             this.ui.hideLoading();
#         }
#     }
# }
#
# new App();
# ```
#
# ```html:frontend/src/index.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Question Generator</title>
#     <link rel="stylesheet" href="css/style.css">
# </head>
# <body>
#     <div class="main-container">
#         <section id="input-section">
#             <h2>Generate Questions</h2>
#             <label for="topic">Topic:</label>
#             <input type="text" id="topic" name="topic" required>
#             <label for="level">Level:</label>
#             <select id="level" name="level">
#                 <option value="Below A1">Below A1</option>
#                 <option value="A1-A2">A1 - A2</option>
#                 <option value="A2-B1">A2 - B1</option>
#                 <option value="Upper B1">Upper B1</option>
#             </select>
#             <button type="button" id="generate-btn">Generate Questions</button>
#         </section>
#
#         <section id="output-section">
#             <h2>Generated Questions</h2>
#             <div id="question-container"></div>
#         </section>
#
#         <div id="loading-dialog" class="loading-modal">
#             <div class="loading-spinner"></div>
#         </div>
#     </div>
#
#     <script type="module" src="js/main.js"></script>
# </body>
# </html>
# ```
#
# To set up and run the project:
#
# 1. Backend setup:
# ```bash
# cd backend
# npm init -y
# npm install express cors dotenv axios
# ```
#
# 2. Create `.env` file in backend folder:
# ```
# PORT=3000
# OPENAI_API_KEY=your_api_key_here
# ```
#
# 3. Frontend setup:
# ```bash
# cd frontend
# npm init -y
# npm install --save-dev live-server
# ```
#
# 4. Add to frontend's package.json:
# ```json
# {
#   "scripts": {
#     "start": "live-server src --port=8080"
#   }
# }
# ```
#
# 5. Run the application:
# ```bash
# # Terminal 1 (Backend)
# cd backend
# node src/server.js
#
# # Terminal 2 (Frontend)
# cd frontend
# npm start
# ```
#
# The CSS file remains the same as in your original code:
#
# ```1:49:frontend/src/css/style.css
# body {
#     font-family: Arial, sans-serif;
# }
#
# .main-container {
#     width: 80%;
#     margin: 0 auto;
#     padding: 20px;
# }
#
# #input-section, #output-section {
#     padding: 20px;
#     border: 1px solid #ddd;
#     margin-top: 20px;
#     background-color: #f9f9f9;
#     border-radius: 5px;
# }
#
# button {
#     padding: 10px 15px;
#     margin-top: 10px;
#     cursor: pointer;
# }
#
# .loading-modal {
#     display: none;
#     position: fixed;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     background-color: rgba(0, 0, 0, 0.5);
#     align-items: center;
#     justify-content: center;
# }
#
# .loading-spinner {
#     border: 8px solid #f3f3f3;
#     border-top: 8px solid #3498db;
#     border-radius: 50%;
#     width: 50px;
#     height: 50px;
#     animation: spin 1s linear infinite;
# }
#
# @keyframes spin {
#     0% { transform: rotate(0deg); }
#     100% { transform: rotate(360deg); }
# }
# ```
#
#
# This structure separates concerns between frontend and backend, making the code more maintainable and scalable.

# %% [markdown]
# `npm install --save-dev live-server`
#
# - live-server là một web server nhẹ với khả năng tự động reload trang khi có thay đổi trong code
# - `--save-dev` flag chỉ định đây là dependency chỉ dùng trong quá trình phát triển, không cần trong production
# - Khi cài đặt xong, live-server sẽ được thêm vào phần "devDependencies" trong package.json
#
#
# ```bash
# {
#     "scripts": {
#         "start": "live-server src --port=8080"
#     },
#     "devDependencies": {
#         "live-server": "^1.2.2"
#     }
# }
# ```
